# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import geocoder
import folium
from geopy.geocoders import Nominatim # convert an address to langtitude and longitude
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# import k-means from clustering stage
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import math

# %%
url = "https://vi.wikipedia.org/wiki/Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh"

r  = requests.get(url)

data = r.text

soup = BeautifulSoup(data,'lxml')

# %%
df = []
for i in soup.find_all("table",class_="wikitable sortable")[0].find_all("tr"):
    ls = []
    for j in i.find_all("td"):
        ls.append(j.get_text())
    df.append(ls)
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#                                                  0            1         2    \
# 0                                               None         None      None
# 1  \n\n\nTên\n\nDiện tích (km²)\nDân số (người)\n...  Quận (19)\n  Quận 1\n
# 2                                               None         None      None
# 3                                        Quận (19)\n         None      None
# 4                                           Quận 1\n         7,72   142.000
#
#            3        4            5         6      7        8            9    \
# 0         None     None         None      None   None     None         None
# 1         7,72  142.000  10 phường\n  Quận 2\n  49,79  180.000  11 phường\n
# 2         None     None         None      None   None     None         None
# 3         None     None         None      None   None     None         None
# 4  10 phường\n     None         None      None   None     None         None
#
#    ...                  91         92      93       94                   95   \
# 0  ...                 None       None    None     None                 None
# 1  ...  1 thị trấn, 20 xã\n  Hóc Môn\n  109,17  542.000  1 thị trấn, 11 xã\n
# 2  ...                 None       None    None     None                 None
# 3  ...                 None       None    None     None                 None
# 4  ...                 None       None    None     None                 None
#
#         96      97       98                  99    100
# 0      None    None     None                None  None
# 1  Nhà Bè\n  100,43  206.000  1 thị trấn, 6 xã\n    \n
# 2      None    None     None                None  None
# 3      None    None     None                None  None
# 4      None    None     None                None  None
#
# [5 rows x 101 columns]

# %%
df.drop(labels=[0,1,2,3,16,24],inplace=True)
df = df.iloc[:,0:3]
df.columns=['District Name','Acreage (Km2)','Population']
df.reset_index(drop=True,inplace=True)
# Remove EOL "\n" String in dataset
for i in df.columns:
    df[i] = df[i].str.replace("\n","",regex=True)

# %%
df['Acreage (Km2)'] = df['Acreage (Km2)'].str.replace(",",".",regex=True)
df['Population'] = df['Population'].str.replace(".","",regex=True)
df['Acreage (Km2)'].astype(float)
df['Population'].astype(int)
# Out:
# 0     142000
# 1     180000
# 2     190000
# 3     175000
# 4     159000
# 5     233000
# 6     360000
# 7     424000
# 8     397000
# 9     234000
# 10    209000
# 11    620000
# 12    784000
# 13    499000
# 14    676000
# 15    163000
# 16    474000
# 17    485000
# 18    592000
# 19    705000
# 20     71000
# 21    462000
# 22    542000
# 23    206000
# Name: Population, dtype: int32

# %%
df.head()
# Out:
#   District Name Acreage (Km2) Population
# 0        Quận 1          7.72     142000
# 1        Quận 2         49.79     180000
# 2        Quận 3          4.92     190000
# 3        Quận 4          4.18     175000
# 4        Quận 5          4.27     159000

# %%
df.shape
# Out:
# (24, 3)

# %%
df_hcmc = df.copy()

# %% [markdown]
# ### Prepare for fourquare dataframe

# %%
CLIENT_ID = 'TYNGSEF0SNXTWZU5JEPMP3Z3BSCBA2TQEK2ODCGA114NG4GG' # your Foursquare ID
CLIENT_SECRET = 'G21UECLTFUK3MLIFP4SQK03OR1JMMDI4EPQS4J12TF0CFMP3' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TYNGSEF0SNXTWZU5JEPMP3Z3BSCBA2TQEK2ODCGA114NG4GG
# CLIENT_SECRET:G21UECLTFUK3MLIFP4SQK03OR1JMMDI4EPQS4J12TF0CFMP3

# %%
df_hcm_cor = pd.read_csv("HCM district coordinates.csv")

# %%
df_hcm_cor.head()
# Out:
#   District Name   Latitude   Longitude
# 0        Quận 1  10.777369  106.696646
# 1        Quận 2  10.782377  106.754713
# 2        Quận 3  10.780681  106.680866
# 3        Quận 4  10.758388  106.702021
# 4        Quận 5  10.755418  106.667333

# %%
df_hcm_cor = df_hcm_cor.sort_values(by="District Name",ascending=True)
df_hcmc = df_hcmc.sort_values(by="District Name",ascending=True)

# %%
df_hcm_cor['District Name'] == df_hcmc['District Name']
# Out:
# 19    True
# 13    True
# 12    True
# 20    True
# 21    True
# 14    True
# 22    True
# 23    True
# 15    True
# 0     True
# 9     True
# 10    True
# 11    True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 18    True
# 16    True
# 17    True
# Name: District Name, dtype: bool

# %%
df_hcmc = df_hcmc.merge(df_hcm_cor.iloc[:,1:3],left_index=True,right_index=True)

# %%
df_hcmc
# Out:
#    District Name Acreage (Km2) Population   Latitude   Longitude
# 19    Bình Chánh        252.56     705000  10.724583  106.575197
# 13    Bình Thạnh         20.78     499000  10.812639  106.714579
# 12      Bình Tân         52.02     784000  10.770324  106.599978
# 20       Cần Giờ        704.45      71000  10.535622  106.854503
# 21        Củ Chi        434.77     462000  11.008502  106.518123
# 14        Gò Vấp         19.73     676000  10.837427  106.666492
# 22       Hóc Môn        109.17     542000  10.891521  106.600013
# 23        Nhà Bè        100.43     206000  10.650182  106.729357
# 15     Phú Nhuận          4.88     163000  10.799939  106.677777
# 0         Quận 1          7.72     142000  10.777369  106.696646
# 9        Quận 10          5.72     234000  10.772549  106.669084
# 10       Quận 11          5.14     209000  10.764343  106.646925
# 11       Quận 12         52.74     620000  10.866624  106.657436
# 1         Quận 2         49.79     180000  10.782377  106.754713
# 2         Quận 3          4.92     190000  10.780681  106.680866
# 3         Quận 4          4.18     175000  10.758388  106.702021
# 4         Quận 5          4.27     159000  10.755418  106.667333
# 5         Quận 6          7.14     233000  10.747072  106.635760
# 6         Quận 7         35.69     360000  10.734714  106.725938
# 7         Quận 8         19.11     424000  10.730639  106.637651
# 8         Quận 9           114     397000  10.826519  106.816712
# 18       Thủ Đức          47.8     592000  10.857137  106.747156
# 16      Tân Bình         22.43     474000  10.810796  106.653959
# 17       Tân Phú         15.97     485000  10.790275  106.628605

# %%
address = 'Ho Chi Minh'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Ho Chi Minh City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Ho Chi Minh City are 10.7758439, 106.7017555.

# %%
m = folium.Map(location=[latitude, longitude],zoom_start=12)
#url = 'https://cocl.us/sanfran_geojson'
#geo_data_input = f'{url}'
for index,values in df_hcmc.iterrows():
    folium.CircleMarker(
        [values['Latitude'], values['Longitude']],
        radius=2,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(m)  
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'TYNGSEF0SNXTWZU5JEPMP3Z3BSCBA2TQEK2ODCGA114NG4GG' # your Foursquare ID
CLIENT_SECRET = 'G21UECLTFUK3MLIFP4SQK03OR1JMMDI4EPQS4J12TF0CFMP3' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TYNGSEF0SNXTWZU5JEPMP3Z3BSCBA2TQEK2ODCGA114NG4GG
# CLIENT_SECRET:G21UECLTFUK3MLIFP4SQK03OR1JMMDI4EPQS4J12TF0CFMP3

# %%
# type your answer here
def get_foursquare_url(cl_id,cl_se,ver,lat,long,radius):
    url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId=4bf58dd8d48988d1e0931735,5665c7b9498e7d8a4f2c0f06,5e18993feee47d000759b256,4bf58dd8d48988d1a1941735,4bf58dd8d48988d128941735,4bf58dd8d48988d16d941735,54135bf5e4b08f3d2429dfe7,56aa371be4b08b9a8d573508,54f4ba06498e2cf5561da814,4bf58dd8d48988d18d941735,4bf58dd8d48988d1f0941735&intent=browse'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        long, 
        radius, 
        )
    return url

# %%
def getNearbyVenues(names, latitudes, longitudes, acreage):
    CLIENT_ID = 'TYNGSEF0SNXTWZU5JEPMP3Z3BSCBA2TQEK2ODCGA114NG4GG' # your Foursquare ID
    CLIENT_SECRET = 'G21UECLTFUK3MLIFP4SQK03OR1JMMDI4EPQS4J12TF0CFMP3' # your Foursquare Secret
    venues_list=[]
    for name, lat, lng,acr in zip(names, latitudes, longitudes, acreage):
        print(name)
            
        # create the API request URL
        url = get_foursquare_url(CLIENT_ID,CLIENT_SECRET,lat,lng,math.sqrt(float(acr)/float(3.14)))
            
        # make the GET request
        results = requests.get(url).json()
        print(results)
        
        # return only relevant information for each nearby venue
        #venues_list.append([(
        #    name, 
        #    lat, 
        #    lng, 
        #    v[0]['id'],
        #    v[0]['name'],
        #    v[0]['location']['lat'], 
        #    v[0]['location']['lng']) for v in results])
        #for v in results:
        #    print(v)
    print(venues_list)
    #nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    #nearby_venues.columns = ['Neighborhood', 
    #              'Neighborhood Latitude', 
    #              'Neighborhood Longitude', 
    #              'Venue Id',
    #              'Venue Name',
    #              'Venue Latitude', 
    #              'Venue Longitude']
    
    return(nearby_venues)

# %%
coffee_venues = getNearbyVenues(names=df_hcmc['District Name'],latitudes = df_hcmc['Latitude'],longitudes = df_hcmc['Longitude'],acreage = df_hcmc['Acreage (Km2)'])
# Out:
# Bình Chánh
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb5e4660a9f001b7fce10'}, 'response': {}}
# Bình Thạnh
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb6aab9a389001beaf2f8'}, 'response': {}}
# Bình Tân
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb5d9aba297001bfaf110'}, 'response': {}}
# Cần Giờ
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb6b70cc1fd001bcebec4'}, 'response': {}}
# Củ Chi
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb716f7706a001bd0adc6'}, 'response': {}}
# Gò Vấp
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb66b98205d001be2686c'}, 'response': {}}
# Hóc Môn
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb71a618f43001c9d36b3'}, 'response': {}}
# Nhà Bè
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb7229fcb92001b90e6ca'}, 'response': {}}
# Phú Nhuận
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb5ddaba297001bfb00fb'}, 'response': {}}
# Quận 1
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb63a95feaf001ba655d1'}, 'response': {}}
# Quận 10
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb60540a7ea001b3d2c0c'}, 'response': {}}
# Quận 11
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb6d1ad1ab4001b3f972b'}, 'response': {}}
# Quận 12
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb6d96d8c56001b749671'}, 'response': {}}
# Quận 2
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb60dbae9a2001caadbe0'}, 'response': {}}
# Quận 3
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb6d0d03993001b605dd4'}, 'response': {}}
# Quận 4
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb6521835dd001b6645fd'}, 'response': {}}
# Quận 5
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb720f7706a001bd0d8a1'}, 'response': {}}
# Quận 6
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb7030de0d9001bf73e3d'}, 'response': {}}
# Quận 7
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb6d5d03993001b60716e'}, 'response': {}}
# Quận 8
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb56a02a17200240807f6'}, 'response': {}}
# Quận 9
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb5e9aba297001bfb335b'}, 'response': {}}
# Thủ Đức
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb78a5fb726001b4888c4'}, 'response': {}}
# Tân Bình
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb65871c428001b214491'}, 'response': {}}
# Tân Phú
# {'meta': {'code': 410, 'errorType': 'param_error', 'errorDetail': 'The Foursquare API no longer supports requests that do not pass in a version parameter. For more details see https://developer.foursquare.com/overview/versioning', 'requestId': '5e5fb65a1835dd001b66677c'}, 'response': {}}
# []

# %%
nearby_venues
# Out:
#                           id                                             name  \
# 0   5ca8c8c7a4b51b0039410171                                        Starbucks
# 1   5881f1630802cb5c60818010                              The Cafe Apartments
# 2   524d970d11d2e6f625dcbacb           Starbucks (Starbucks Coffee Rex Hotel)
# 3   50ae4436e4b04c937a56de9c   Starbucks (Starbucks Coffee @ New World Hotel)
# 4   59776705b8fd9d580a2cd730                                        Starbucks
# 5   59997bb15d0fea4b39463d94                                Starbucks Reserve
# 6   4bf016fb3a002d7fe0a585a4                                  Caravelle Hotel
# 7   554faad7498e38786638336f                                        Starbucks
# 8   53661368498e9da412ec776c                                        Starbucks
# 9   56764e09498eca1773f719b4                                      Cộng Cà Phê
# 10  53cc8b78498ec6ddfb2a113d                                The Workshop Cafe
# 11  5a658ee26dcf043630323548                       The Coffee House Signature
# 12  4bf910195efe2d7f87a86b34                             Annam Gourmet Market
# 13  57c80576498eec7de589ffc0                                      Cộng Cà phê
# 14  5a86cbe1a9fe1264b7e7db05                                 The Running Bean
# 15  5942240d1f8ed601a7a7192f                                         Vietphin
# 16  5e0c512ab6f1fd0008988893                                     Okkio Coffee
# 17  5df8cee57275f80008d74ce1                                   greyhound cafe
# 18  560c97bd498eb2ee6d645379                                        Starbucks
# 19  5671a64a498edd1c61585e09    Phúc Long Coffee & Tea Express Phạm Hồng Thái
# 20  5270f0df498efc7b6c5c7f23  The Coffee Bean & Tea Leaf Hàn Thuyên - Pasteur
# 21  5b48dd5690d1ed002b69601d                  The Coffee House - Phạm Ngũ Lão
# 22  5e48a83af03dfb0008f21041             Là Việt Coffee (Bà Huyện Thanh Quan)
# 23  5d4ed8a1a3c43e0008233f99                                  The Coffee Club
# 24  54018ba6498e6650fc7f69ac                             The Vintage Emporium
# 25  4bc8552e8b7c9c74cbdf37cf                         Trung Nguyên Legend Café
# 26  5b80c925b9a5a8002c909e77                                  Le cafe de Dinh
# 27  5a314bbc06fb6008dec875f0                                   The Egg Coffee
# 28  5c262498f870fd002c24a5e3                                    Phin & Bean 2
# 29  5c9b376679f6c70039a11929                                VCR: The Roastery
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 1   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583327600    False
# 2   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 3   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 4   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 5   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 6   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1583327600    False
# 7   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 8   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 9   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583327600    False
# 10  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 11  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 12  [{'id': '4bf58dd8d48988d1f5941735', 'name': 'G...  v-1583327600    False
# 13  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583327600    False
# 14  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 15  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 16  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 17  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583327600    False
# 18  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 19  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583327600    False
# 20  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583327600    False
# 21  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 22  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 23  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 24  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583327600    False
# 25  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583327600    False
# 26  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 27  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
# 28  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583327600    False
# 29  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583327600    False
#
#                                      location.address  location.lat  \
# 0                                           65 Lê Lợi     10.773784
# 1   The Cafe Apartment, 42 Nguyen Hue Street, Dist...     10.773743
# 2                                146 - 148 Pasteur St     10.775614
# 3                              76 Le Lai St., Dist. 1     10.771221
# 4            241bis Cach Mang Thang 8 St., District 3     10.776537
# 5                  11 - 13 Han Thuyen St., District 1     10.778961
# 6                       19 Lam Son Square, District 1     10.776482
# 7                          39 Le Duan St., District 1     10.781078
# 8                  191-193 Đề Thám Street, District 1     10.767544
# 9                              26 Lý Tự Trọng, Quận 1     10.777917
# 10        No 27, Floor 2, Ngo Duc Ke Str., District 1     10.773551
# 11                                19B Pham Ngoc Thach     10.783805
# 12                    16-18 Hai Bà Trưng St., Dist. 1     10.776540
# 13                                       Mạc Thị Bưởi     10.776145
# 14                                                115     10.772904
# 15                              89B Cach Mang Thang 8     10.772864
# 16                                35 Nguyễn Văn Tráng     10.770767
# 17                               92 Nam Ky Khoi Nghia     10.772053
# 18                      99 Nguyen Hue St., District 1     10.773740
# 19                          42 Phạm Hồng Thái, Quận 1     10.771250
# 20                              27 Hàn Thuyên, Quận 1     10.778586
# 21                                   159 Phạm Ngũ Lão     10.769085
# 22                             16 Bà Huyện Thanh Quan     10.776227
# 23                                5bis, Han Thuyen St     10.779146
# 24                              95b Nguyen Van Thu st     10.790146
# 25                    7 Nguyen Van Chiem St., Dist. 1     10.781598
# 26                                                NaN     10.776683
# 27                                 178 Đường Bùi Viện     10.766551
# 28                                   57 Nguyễn Du, Q1     10.779380
# 29                      Hẻm Số 7 Nguyễn Thị Minh Khai     10.787119
#
#     location.lng                            location.labeledLatLngs  \
# 0     106.700950  [{'label': 'display', 'lat': 10.773784, 'lng':...
# 1     106.703940  [{'label': 'display', 'lat': 10.77374289584670...
# 2     106.700530  [{'label': 'display', 'lat': 10.77561375300064...
# 3     106.693656  [{'label': 'display', 'lat': 10.77122058818865...
# 4     106.683749  [{'label': 'display', 'lat': 10.77653679632438...
# 5     106.698185  [{'label': 'display', 'lat': 10.77896139444801...
# 6     106.703359  [{'label': 'display', 'lat': 10.77648195838112...
# 7     106.700207  [{'label': 'display', 'lat': 10.781078, 'lng':...
# 8     106.693949  [{'label': 'display', 'lat': 10.76754409344893...
# 9     106.701266  [{'label': 'display', 'lat': 10.77791742055850...
# 10    106.705586  [{'label': 'display', 'lat': 10.773551, 'lng':...
# 11    106.694517  [{'label': 'display', 'lat': 10.78380477863848...
# 12    106.705011  [{'label': 'display', 'lat': 10.77653977390392...
# 13    106.705418  [{'label': 'display', 'lat': 10.77614482823662...
# 14    106.703347  [{'label': 'display', 'lat': 10.77290409158849...
# 15    106.690708  [{'label': 'display', 'lat': 10.772864, 'lng':...
# 16    106.691746  [{'label': 'display', 'lat': 10.770767, 'lng':...
# 17    106.700689  [{'label': 'display', 'lat': 10.772053, 'lng':...
# 18    106.704146  [{'label': 'display', 'lat': 10.77374015232173...
# 19    106.695478  [{'label': 'display', 'lat': 10.77125013773880...
# 20    106.697955  [{'label': 'display', 'lat': 10.77858554651666...
# 21    106.694568  [{'label': 'display', 'lat': 10.769085, 'lng':...
# 22    106.688895  [{'label': 'display', 'lat': 10.776227, 'lng':...
# 23    106.698623  [{'label': 'display', 'lat': 10.779146, 'lng':...
# 24    106.699208  [{'label': 'display', 'lat': 10.79014556375252...
# 25    106.698333  [{'label': 'display', 'lat': 10.78159842056065...
# 26    106.697201  [{'label': 'display', 'lat': 10.776683, 'lng':...
# 27    106.692064  [{'label': 'display', 'lat': 10.76655080773140...
# 28    106.700275  [{'label': 'display', 'lat': 10.77938, 'lng': ...
# 29    106.703312  [{'label': 'display', 'lat': 10.787119, 'lng':...
#
#     location.distance location.cc         location.state location.country  \
# 0                 617          VN  Thành phố Hồ Chí Minh         Việt Nam
# 1                 893          VN                    NaN         Việt Nam
# 2                 467          VN  Thành phố Hồ Chí Minh         Việt Nam
# 3                 758          VN  Thành phố Hồ Chí Minh         Việt Nam
# 4                1413          VN  Thành phố Hồ Chí Minh         Việt Nam
# 5                 244          VN  Thành phố Hồ Chí Minh         Việt Nam
# 6                 740          VN  Thành phố Hồ Chí Minh         Việt Nam
# 7                 567          VN  Thành phố Hồ Chí Minh         Việt Nam
# 8                1132          VN  Thành phố Hồ Chí Minh         Việt Nam
# 9                 508          VN  Thành phố Hồ Chí Minh         Việt Nam
# 10               1066          VN  Thành phố Hồ Chí Minh         Việt Nam
# 11                753          VN  Thành phố Hồ Chí Minh         Việt Nam
# 12                919          VN  Thành phố Hồ Chí Minh         Việt Nam
# 13                968          VN  Thành phố Hồ Chí Minh         Việt Nam
# 14                885          VN  Thành phố Hồ Chí Minh         Việt Nam
# 15                820          VN  Thành phố Hồ Chí Minh         Việt Nam
# 16                909          VN  Thành phố Hồ Chí Minh         Việt Nam
# 17                738          VN  Thành phố Hồ Chí Minh         Việt Nam
# 18                914          VN  Thành phố Hồ Chí Minh         Việt Nam
# 19                693          VN                    NaN         Việt Nam
# 20                197          VN  Thành phố Hồ Chí Minh         Việt Nam
# 21                949          VN  Thành phố Hồ Chí Minh         Việt Nam
# 22                857          VN  Thành phố Hồ Chí Minh         Việt Nam
# 23                293          VN  Thành phố Hồ Chí Minh         Việt Nam
# 24               1449          VN  Thành phố Hồ Chí Minh         Việt Nam
# 25                505          VN  Thành phố Hồ Chí Minh         Việt Nam
# 26                 97          VN  Thành phố Hồ Chí Minh         Việt Nam
# 27               1304          VN  Thành phố Hồ Chí Minh         Việt Nam
# 28                455          VN  Thành phố Hồ Chí Minh         Việt Nam
# 29               1307          VN  Thành phố Hồ Chí Minh         Việt Nam
#
#                             location.formattedAddress  \
# 0        [65 Lê Lợi, Thành phố Hồ Chí Minh, Việt Nam]
# 1   [The Cafe Apartment, 42 Nguyen Hue Street, Dis...
# 2   [146 - 148 Pasteur St (Le Thanh Ton), Thành ph...
# 3   [76 Le Lai St., Dist. 1 (btw. Pham Hong Thai S...
# 4   [241bis Cach Mang Thang 8 St., District 3 (Die...
# 5   [11 - 13 Han Thuyen St., District 1, Thành phố...
# 6   [19 Lam Son Square, District 1, Thành phố Hồ C...
# 7   [39 Le Duan St., District 1, Thành phố Hồ Chí ...
# 8   [191-193 Đề Thám Street, District 1 (Bùi Viện)...
# 9   [26 Lý Tự Trọng, Quận 1, Thành phố Hồ Chí Minh...
# 10  [No 27, Floor 2, Ngo Duc Ke Str., District 1 (...
# 11  [19B Pham Ngoc Thach, Thành phố Hồ Chí Minh, T...
# 12  [16-18 Hai Bà Trưng St., Dist. 1 (Đông Du St.)...
# 13  [Mạc Thị Bưởi, Thành phố Hồ Chí Minh, Thành ph...
# 14  [115 (Hồ Tùng Mậu), Thành phố Hồ Chí Minh, Thà...
# 15  [89B Cach Mang Thang 8, Thành phố Hồ Chí Minh,...
# 16  [35 Nguyễn Văn Tráng, Thành phố Hồ Chí Minh, T...
# 17  [92 Nam Ky Khoi Nghia, Thành phố Hồ Chí Minh, ...
# 18  [99 Nguyen Hue St., District 1, Thành phố Hồ C...
# 19  [42 Phạm Hồng Thái, Quận 1, hồ chí minh, Việt ...
# 20  [27 Hàn Thuyên, Quận 1 (Pasteur), Thành phố Hồ...
# 21  [159 Phạm Ngũ Lão, Thành phố Hồ Chí Minh, Thàn...
# 22  [16 Bà Huyện Thanh Quan, Thành phố Hồ Chí Minh...
# 23  [5bis, Han Thuyen St, Thành phố Hồ Chí Minh, T...
# 24  [95b Nguyen Van Thu st (Phan Ke Binh), Thành p...
# 25  [7 Nguyen Van Chiem St., Dist. 1 (Nguyễn Văn C...
# 26  [Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh,...
# 27  [178 Đường Bùi Viện, Thành phố Hồ Chí Minh, Th...
# 28  [57 Nguyễn Du, Q1, Thành phố Hồ Chí Minh, Thàn...
# 29  [Hẻm Số 7 Nguyễn Thị Minh Khai, Thành phố Hồ C...
#
#                                 location.crossStreet location.postalCode  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                       Le Thanh Ton              700000
# 3   btw. Pham Hong Thai St. and Nguyen Thi Nghia St.                 NaN
# 4                                      Dien Bien Phu                 NaN
# 5                                                NaN                 NaN
# 6                                                NaN                 NaN
# 7                                                NaN                 NaN
# 8                                           Bùi Viện                 NaN
# 9                                                NaN                 NaN
# 10                                    Dong Khoi Str.                 NaN
# 11                                               NaN              722437
# 12                                       Đông Du St.               70000
# 13                                               NaN                 NaN
# 14                                       Hồ Tùng Mậu              700000
# 15                                               NaN              711012
# 16                                               NaN                 NaN
# 17                                               NaN                 NaN
# 18                                               NaN                 NaN
# 19                                               NaN                 NaN
# 20                                           Pasteur                 NaN
# 21                                               NaN                 NaN
# 22                                               NaN                 NaN
# 23                                               NaN                 NaN
# 24                                      Phan Ke Binh                 NaN
# 25                                  Nguyễn Văn Chiêm              700000
# 26                                               NaN                 NaN
# 27                                               NaN              711266
# 28                                               NaN                 NaN
# 29                                               NaN                 NaN
#
#             location.city venuePage.id location.neighborhood
# 0                     NaN          NaN                   NaN
# 1                     NaN          NaN                   NaN
# 2   Thành phố Hồ Chí Minh          NaN                   NaN
# 3   Thành phố Hồ Chí Minh     76915000                   NaN
# 4   Thành phố Hồ Chí Minh          NaN                   NaN
# 5   Thành phố Hồ Chí Minh          NaN                   NaN
# 6   Thành phố Hồ Chí Minh          NaN                   NaN
# 7   Thành phố Hồ Chí Minh          NaN                   NaN
# 8   Thành phố Hồ Chí Minh          NaN                   NaN
# 9   Thành phố Hồ Chí Minh          NaN                   NaN
# 10  Thành phố Hồ Chí Minh          NaN              Bến Nghé
# 11  Thành phố Hồ Chí Minh          NaN                   NaN
# 12  Thành phố Hồ Chí Minh          NaN                   NaN
# 13  Thành phố Hồ Chí Minh          NaN                   NaN
# 14  Thành phố Hồ Chí Minh          NaN                   NaN
# 15  Thành phố Hồ Chí Minh          NaN                   NaN
# 16  Thành phố Hồ Chí Minh          NaN                   NaN
# 17  Thành phố Hồ Chí Minh          NaN                   NaN
# 18  Thành phố Hồ Chí Minh          NaN                   NaN
# 19            hồ chí minh          NaN                   NaN
# 20  Thành phố Hồ Chí Minh          NaN                   NaN
# 21  Thành phố Hồ Chí Minh          NaN                   NaN
# 22  Thành phố Hồ Chí Minh          NaN                   NaN
# 23  Thành phố Hồ Chí Minh          NaN                   NaN
# 24  Thành phố Hồ Chí Minh     97713529                   NaN
# 25  Thành phố Hồ Chí Minh          NaN                   NaN
# 26  Thành phố Hồ Chí Minh          NaN                   NaN
# 27  Thành phố Hồ Chí Minh          NaN                   NaN
# 28  Thành phố Hồ Chí Minh          NaN                   NaN
# 29  Thành phố Hồ Chí Minh          NaN                   NaN

# %%
results = requests.get(get_foursquare_url(CLIENT_ID,CLIENT_SECRET,VERSION,10.790275,106.628605,2250)).json()

# %%
venue = results['response']['venues']

# %%
venue[0]['location']['lat']
# Out:
# 10.787477

# %%
venue
# Out:
# [{'id': '5e5240407f39440008eba736',
#   'name': 'Cao Coffee',
#   'location': {'lat': 10.787477,
#    'lng': 106.62361,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.787477,
#      'lng': 106.62361}],
#    'distance': 628,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '53a9a04f498e1e9a997ca1b6',
#   'name': 'Starbucks',
#   'location': {'address': '1/1 Truong Chinh St., Tan Phu Dist.',
#    'lat': 10.806511172818963,
#    'lng': 106.63469136407473,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.806511172818963,
#      'lng': 106.63469136407473}],
#    'distance': 1926,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['1/1 Truong Chinh St., Tan Phu Dist.',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '5cc91ec05ba04600396e48e1',
#   'name': 'Bodyfriend Massage Coffee',
#   'location': {'lat': 10.800833,
#    'lng': 106.61616,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.800833,
#      'lng': 106.61616}],
#    'distance': 1798,
#    'cc': 'VN',
#    'city': 'Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Hồ Chí Minh', 'Việt Nam']},
#   'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#     'name': 'Corporate Coffee Shop',
#     'pluralName': 'Corporate Coffee Shops',
#     'shortName': 'Corporate Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '5b288ec50868a2002c96b412',
#   'name': 'Wayne’s Coffee',
#   'location': {'address': 'Ground Floor Viettel Complex Building, 285 Cách Mạng Tháng Tám, Phường 12',
#    'lat': 10.78922,
#    'lng': 106.63663,
#    'labeledLatLngs': [{'label': 'display', 'lat': 10.78922, 'lng': 106.63663}],
#    'distance': 885,
#    'postalCode': '700000',
#    'cc': 'VN',
#    'city': 'Ho Chi Minh City - Quận 10',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Ground Floor Viettel Complex Building, 285 Cách Mạng Tháng Tám, Phường 12',
#     'Ho Chi Minh City - Quận 10',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '4f1a3b13e4b0d1a654726006',
#   'name': 'vuon tre',
#   'location': {'address': '42 Đồng Xoài, phường 13, Tân Bình district, Prey Nokor',
#    'lat': 10.80117863823167,
#    'lng': 106.64589014949412,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.80117863823167,
#      'lng': 106.64589014949412}],
#    'distance': 2246,
#    'cc': 'VN',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['42 Đồng Xoài, phường 13, Tân Bình district, Prey Nokor',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '5b8ca052968f31002c043a94',
#   'name': 'The Coffee House',
#   'location': {'crossStreet': '184 To Hieu St., Tan Phu Dist.',
#    'lat': 10.7731495,
#    'lng': 106.627594,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.7731495,
#      'lng': 106.627594}],
#    'distance': 1909,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['184 To Hieu St., Tan Phu Dist.',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '591d40429b047319cb3f01cb',
#   'name': 'The Coffee House',
#   'location': {'address': 'Độc Lập',
#    'lat': 10.792879,
#    'lng': 106.628855,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.792879,
#      'lng': 106.628855}],
#    'distance': 291,
#    'postalCode': '760003',
#    'cc': 'VN',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Độc Lập', 'Thành phố Hồ Chí Minh', 'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '4f86d20ae4b05dd564805736',
#   'name': 'Cafe 55 phan đình phùng',
#   'location': {'address': '55',
#    'crossStreet': 'Phan đình phùng',
#    'lat': 10.78959174365355,
#    'lng': 106.63051477678941,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.78959174365355,
#      'lng': 106.63051477678941}],
#    'distance': 222,
#    'cc': 'VN',
#    'city': 'Hcm',
#    'country': 'Việt Nam',
#    'formattedAddress': ['55 (Phan đình phùng)', 'Hcm', 'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '52c6b8a7498e32caa049a983',
#   'name': 'Food Court @ AEON Mall',
#   'location': {'lat': 10.801273228474118,
#    'lng': 106.61788012492114,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.801273228474118,
#      'lng': 106.61788012492114}],
#    'distance': 1695,
#    'cc': 'VN',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d128941735',
#     'name': 'Cafeteria',
#     'pluralName': 'Cafeterias',
#     'shortName': 'Cafeteria',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '5bcafa784c954c002c6c81d4',
#   'name': 'the coffee house',
#   'location': {'lat': 10.786697,
#    'lng': 106.64347,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.786697,
#      'lng': 106.64347}],
#    'distance': 1673,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '4c03465b187ec928ea85b57b',
#   'name': 'Highlands Coffee',
#   'location': {'address': '364 Cong Hoa St.',
#    'lat': 10.801674745297674,
#    'lng': 106.64025752565973,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.801674745297674,
#      'lng': 106.64025752565973}],
#    'distance': 1798,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['364 Cong Hoa St.',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '59a2ba2a112c6c2b6c3fb89f',
#   'name': 'the coffee house',
#   'location': {'address': '45 Đường Trương Công Định',
#    'lat': 10.795199,
#    'lng': 106.640764,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.795199,
#      'lng': 106.640764}],
#    'distance': 1438,
#    'postalCode': '736784',
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['45 Đường Trương Công Định',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '5222aeaf11d2b150d145d1f2',
#   'name': 'Cafe Valentino',
#   'location': {'lat': 10.780394838244428,
#    'lng': 106.63282888380762,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.780394838244428,
#      'lng': 106.63282888380762}],
#    'distance': 1192,
#    'cc': 'VN',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '4f654d2ee4b041039e868325',
#   'name': 'J coffee',
#   'location': {'lat': 10.7703854163638,
#    'lng': 106.63099831949829,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.7703854163638,
#      'lng': 106.63099831949829}],
#    'distance': 2229,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '584bce300037eb460e074177',
#   'name': 'The Coffee House',
#   'location': {'address': '787 LUỸ BÁN BÍCH, QUẬN TÂN PHÚ',
#    'lat': 10.786582,
#    'lng': 106.637224,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.786582,
#      'lng': 106.637224}],
#    'distance': 1028,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['787 LUỸ BÁN BÍCH, QUẬN TÂN PHÚ',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '5dc8e678a8957c00081df418',
#   'name': 'Ultra Coffee',
#   'location': {'lat': 10.784235,
#    'lng': 106.626823,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.784235,
#      'lng': 106.626823}],
#    'distance': 700,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '5700b632cd10008f7be44328',
#   'name': 'Wings Cafe',
#   'location': {'address': 'Tầng 1, Pandora City',
#    'crossStreet': 'Trường Chinh',
#    'lat': 10.806622,
#    'lng': 106.63429,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.806622,
#      'lng': 106.63429}],
#    'distance': 1922,
#    'cc': 'VN',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Tầng 1, Pandora City (Trường Chinh)', 'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '518dc692498ec27130652e6d',
#   'name': 'The Coffee Pi',
#   'location': {'address': '53 Nguyễn Hồng Đào',
#    'lat': 10.796602,
#    'lng': 106.643337,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.796602,
#      'lng': 106.643337}],
#    'distance': 1758,
#    'cc': 'VN',
#    'state': 'Tân Bình',
#    'country': 'Việt Nam',
#    'formattedAddress': ['53 Nguyễn Hồng Đào', 'Tân Bình', 'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '5cbee2699d7468002c0c9786',
#   'name': 'Green House Coffee & Milk Tea',
#   'location': {'address': '27b Sơn Kỳ ,phường Sơn Kỳ , Quận Tân Phú',
#    'lat': 10.804538,
#    'lng': 106.627808,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.804538,
#      'lng': 106.627808}],
#    'distance': 1590,
#    'cc': 'VN',
#    'city': 'Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['27b Sơn Kỳ ,phường Sơn Kỳ , Quận Tân Phú',
#     'Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '4dd91203e4cd37c893d32add',
#   'name': 'Tino Café',
#   'location': {'address': '95 Gò Dầu',
#    'lat': 10.795776898934369,
#    'lng': 106.62539734925114,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.795776898934369,
#      'lng': 106.62539734925114}],
#    'distance': 705,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['95 Gò Dầu',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '54059ec9498ed729c07aa701',
#   'name': 'Cafe Trầm',
#   'location': {'address': '61 Trương Vĩnh Ký, Q.Tân Phú',
#    'lat': 10.793468475341797,
#    'lng': 106.63566589355469,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.793468475341797,
#      'lng': 106.63566589355469}],
#    'distance': 850,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['61 Trương Vĩnh Ký, Q.Tân Phú',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '574ed330498e0286d3c22273',
#   'name': 'MDT Coffee',
#   'location': {'address': 'Level 4, 1/1 Truong Chinh St., Tan Phu Dist',
#    'lat': 10.806717,
#    'lng': 106.63439,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.806717,
#      'lng': 106.63439}],
#    'distance': 1936,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Level 4, 1/1 Truong Chinh St., Tan Phu Dist',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '4fddef6de4b014c45be63c6e',
#   'name': 'Coffee Trở Về Chỗ Cũ',
#   'location': {'address': 'Bau Cat 2',
#    'lat': 10.792645,
#    'lng': 106.645176,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.792645,
#      'lng': 106.645176}],
#    'distance': 1831,
#    'cc': 'VN',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Bau Cat 2', 'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '52c421f6498ed85546a7c845',
#   'name': 'Cà phê Bụi',
#   'location': {'address': '266 Tô Hiệu, Q.Tân Phú',
#    'lat': 10.776060104370117,
#    'lng': 106.62864685058594,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.776060104370117,
#      'lng': 106.62864685058594}],
#    'distance': 1582,
#    'cc': 'VN',
#    'city': 'Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['266 Tô Hiệu, Q.Tân Phú', 'Hồ Chí Minh', 'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '504d67d2e4b02739381edd8e',
#   'name': 'Cà phê LIFE',
#   'location': {'address': 'Tân Sơn Nhì, Q.Tân Phú',
#    'lat': 10.795452432298394,
#    'lng': 106.6294813156128,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.795452432298394,
#      'lng': 106.6294813156128}],
#    'distance': 584,
#    'cc': 'VN',
#    'city': 'Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Tân Sơn Nhì, Q.Tân Phú', 'Hồ Chí Minh', 'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '4f5e06b6e4b03690726a5a5f',
#   'name': 'Trà Sữa Rain',
#   'location': {'address': '41 Tân Canh Q.PN',
#    'lat': 10.787138,
#    'lng': 106.645032,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.787138,
#      'lng': 106.645032}],
#    'distance': 1829,
#    'cc': 'VN',
#    'country': 'Việt Nam',
#    'formattedAddress': ['41 Tân Canh Q.PN', 'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '4fb36808e4b0d0b77bfd4fb0',
#   'name': "No Name Cafe'",
#   'location': {'lat': 10.794742914044358,
#    'lng': 106.6297146311045,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.794742914044358,
#      'lng': 106.6297146311045}],
#    'distance': 511,
#    'cc': 'VN',
#    'country': 'Việt Nam',
#    'formattedAddress': ['Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '518dbfab498e35549a243629',
#   'name': 'Che Cafe',
#   'location': {'address': '78/1',
#    'crossStreet': 'Phan Dinh Phung, Tan Phu',
#    'lat': 10.789010047912598,
#    'lng': 106.6297378540039,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.789010047912598,
#      'lng': 106.6297378540039}],
#    'distance': 187,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['78/1 (Phan Dinh Phung, Tan Phu)',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '58942c8d8b0ebb267aec6d53',
#   'name': 'Viva Star Café',
#   'location': {'address': '61 Truong Cong Dinh St., Tan Binh Dist',
#    'lat': 10.794697,
#    'lng': 106.6405,
#    'labeledLatLngs': [{'label': 'display', 'lat': 10.794697, 'lng': 106.6405}],
#    'distance': 1390,
#    'cc': 'VN',
#    'city': 'Thành phố Hồ Chí Minh',
#    'state': 'Thành phố Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['61 Truong Cong Dinh St., Tan Binh Dist',
#     'Thành phố Hồ Chí Minh',
#     'Thành phố Hồ Chí Minh',
#     'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False},
#  {'id': '4efe66e9be7bbcd4f2463306',
#   'name': 'Cafe Angle',
#   'location': {'address': '405/62/5',
#    'crossStreet': 'Trường Chinh',
#    'lat': 10.799519263162145,
#    'lng': 106.64076726434048,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 10.799519263162145,
#      'lng': 106.64076726434048}],
#    'distance': 1681,
#    'cc': 'VN',
#    'city': 'Hồ Chí Minh',
#    'country': 'Việt Nam',
#    'formattedAddress': ['405/62/5 (Trường Chinh)', 'Hồ Chí Minh', 'Việt Nam']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1583330426',
#   'hasPerk': False}]

# %%
nearby_venues = json_normalize(venue)

# %%
nearby_venues
# Out:
#                           id                           name  \
# 0   5e5240407f39440008eba736                     Cao Coffee
# 1   53a9a04f498e1e9a997ca1b6                      Starbucks
# 2   5cc91ec05ba04600396e48e1      Bodyfriend Massage Coffee
# 3   5b288ec50868a2002c96b412                 Wayne’s Coffee
# 4   4f1a3b13e4b0d1a654726006                       vuon tre
# 5   5b8ca052968f31002c043a94               The Coffee House
# 6   591d40429b047319cb3f01cb               The Coffee House
# 7   4f86d20ae4b05dd564805736        Cafe 55 phan đình phùng
# 8   52c6b8a7498e32caa049a983         Food Court @ AEON Mall
# 9   5bcafa784c954c002c6c81d4               the coffee house
# 10  4c03465b187ec928ea85b57b               Highlands Coffee
# 11  59a2ba2a112c6c2b6c3fb89f               the coffee house
# 12  5222aeaf11d2b150d145d1f2                 Cafe Valentino
# 13  4f654d2ee4b041039e868325                       J coffee
# 14  584bce300037eb460e074177               The Coffee House
# 15  5dc8e678a8957c00081df418                   Ultra Coffee
# 16  5700b632cd10008f7be44328                     Wings Cafe
# 17  518dc692498ec27130652e6d                  The Coffee Pi
# 18  5cbee2699d7468002c0c9786  Green House Coffee & Milk Tea
# 19  4dd91203e4cd37c893d32add                      Tino Café
# 20  54059ec9498ed729c07aa701                      Cafe Trầm
# 21  574ed330498e0286d3c22273                     MDT Coffee
# 22  4fddef6de4b014c45be63c6e           Coffee Trở Về Chỗ Cũ
# 23  52c421f6498ed85546a7c845                     Cà phê Bụi
# 24  504d67d2e4b02739381edd8e                    Cà phê LIFE
# 25  4f5e06b6e4b03690726a5a5f                   Trà Sữa Rain
# 26  4fb36808e4b0d0b77bfd4fb0                  No Name Cafe'
# 27  518dbfab498e35549a243629                       Che Cafe
# 28  58942c8d8b0ebb267aec6d53                 Viva Star Café
# 29  4efe66e9be7bbcd4f2463306                     Cafe Angle
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 1   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 2   [{'id': '5665c7b9498e7d8a4f2c0f06', 'name': 'C...  v-1583330083    False
# 3   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 4   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 5   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 6   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 7   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 8   [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1583330083    False
# 9   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 10  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 11  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 12  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 13  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 14  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 15  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 16  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 17  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 18  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 19  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 20  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 21  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 22  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 23  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 24  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 25  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 26  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 27  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1583330083    False
# 28  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
# 29  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1583330083    False
#
#     location.lat  location.lng  \
# 0      10.787477    106.623610
# 1      10.806511    106.634691
# 2      10.800833    106.616160
# 3      10.789220    106.636630
# 4      10.801179    106.645890
# 5      10.773150    106.627594
# 6      10.792879    106.628855
# 7      10.789592    106.630515
# 8      10.801273    106.617880
# 9      10.786697    106.643470
# 10     10.801675    106.640258
# 11     10.795199    106.640764
# 12     10.780395    106.632829
# 13     10.770385    106.630998
# 14     10.786582    106.637224
# 15     10.784235    106.626823
# 16     10.806622    106.634290
# 17     10.796602    106.643337
# 18     10.804538    106.627808
# 19     10.795777    106.625397
# 20     10.793468    106.635666
# 21     10.806717    106.634390
# 22     10.792645    106.645176
# 23     10.776060    106.628647
# 24     10.795452    106.629481
# 25     10.787138    106.645032
# 26     10.794743    106.629715
# 27     10.789010    106.629738
# 28     10.794697    106.640500
# 29     10.799519    106.640767
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 10.787477, 'lng':...                628
# 1   [{'label': 'display', 'lat': 10.80651117281896...               1926
# 2   [{'label': 'display', 'lat': 10.800833, 'lng':...               1798
# 3   [{'label': 'display', 'lat': 10.78922, 'lng': ...                885
# 4   [{'label': 'display', 'lat': 10.80117863823167...               2246
# 5   [{'label': 'display', 'lat': 10.7731495, 'lng'...               1909
# 6   [{'label': 'display', 'lat': 10.792879, 'lng':...                291
# 7   [{'label': 'display', 'lat': 10.78959174365355...                222
# 8   [{'label': 'display', 'lat': 10.80127322847411...               1695
# 9   [{'label': 'display', 'lat': 10.786697, 'lng':...               1673
# 10  [{'label': 'display', 'lat': 10.80167474529767...               1798
# 11  [{'label': 'display', 'lat': 10.795199, 'lng':...               1438
# 12  [{'label': 'display', 'lat': 10.78039483824442...               1192
# 13  [{'label': 'display', 'lat': 10.7703854163638,...               2229
# 14  [{'label': 'display', 'lat': 10.786582, 'lng':...               1028
# 15  [{'label': 'display', 'lat': 10.784235, 'lng':...                700
# 16  [{'label': 'display', 'lat': 10.806622, 'lng':...               1922
# 17  [{'label': 'display', 'lat': 10.796602, 'lng':...               1758
# 18  [{'label': 'display', 'lat': 10.804538, 'lng':...               1590
# 19  [{'label': 'display', 'lat': 10.79577689893436...                705
# 20  [{'label': 'display', 'lat': 10.79346847534179...                850
# 21  [{'label': 'display', 'lat': 10.806717, 'lng':...               1936
# 22  [{'label': 'display', 'lat': 10.792645, 'lng':...               1831
# 23  [{'label': 'display', 'lat': 10.77606010437011...               1582
# 24  [{'label': 'display', 'lat': 10.79545243229839...                584
# 25  [{'label': 'display', 'lat': 10.787138, 'lng':...               1829
# 26  [{'label': 'display', 'lat': 10.79474291404435...                511
# 27  [{'label': 'display', 'lat': 10.78901004791259...                187
# 28  [{'label': 'display', 'lat': 10.794697, 'lng':...               1390
# 29  [{'label': 'display', 'lat': 10.79951926316214...               1681
#
#    location.cc               location.city         location.state  \
# 0           VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 1           VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 2           VN                 Hồ Chí Minh                    NaN
# 3           VN  Ho Chi Minh City - Quận 10  Thành phố Hồ Chí Minh
# 4           VN                         NaN  Thành phố Hồ Chí Minh
# 5           VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 6           VN                         NaN  Thành phố Hồ Chí Minh
# 7           VN                         Hcm                    NaN
# 8           VN                         NaN                    NaN
# 9           VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 10          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 11          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 12          VN                         NaN                    NaN
# 13          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 14          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 15          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 16          VN                         NaN                    NaN
# 17          VN                         NaN               Tân Bình
# 18          VN                 Hồ Chí Minh  Thành phố Hồ Chí Minh
# 19          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 20          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 21          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 22          VN                         NaN                    NaN
# 23          VN                 Hồ Chí Minh                    NaN
# 24          VN                 Hồ Chí Minh                    NaN
# 25          VN                         NaN                    NaN
# 26          VN                         NaN                    NaN
# 27          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 28          VN       Thành phố Hồ Chí Minh  Thành phố Hồ Chí Minh
# 29          VN                 Hồ Chí Minh                    NaN
#
#    location.country                          location.formattedAddress  \
# 0          Việt Nam  [Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh,...
# 1          Việt Nam  [1/1 Truong Chinh St., Tan Phu Dist., Thành ph...
# 2          Việt Nam                            [Hồ Chí Minh, Việt Nam]
# 3          Việt Nam  [Ground Floor Viettel Complex Building, 285 Cá...
# 4          Việt Nam  [42 Đồng Xoài, phường 13, Tân Bình district, P...
# 5          Việt Nam  [184 To Hieu St., Tan Phu Dist., Thành phố Hồ ...
# 6          Việt Nam         [Độc Lập, Thành phố Hồ Chí Minh, Việt Nam]
# 7          Việt Nam              [55 (Phan đình phùng), Hcm, Việt Nam]
# 8          Việt Nam                                         [Việt Nam]
# 9          Việt Nam  [Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh,...
# 10         Việt Nam  [364 Cong Hoa St., Thành phố Hồ Chí Minh, Thàn...
# 11         Việt Nam  [45 Đường Trương Công Định, Thành phố Hồ Chí M...
# 12         Việt Nam                                         [Việt Nam]
# 13         Việt Nam  [Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh,...
# 14         Việt Nam  [787 LUỸ BÁN BÍCH, QUẬN TÂN PHÚ, Thành phố Hồ ...
# 15         Việt Nam  [Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh,...
# 16         Việt Nam  [Tầng 1, Pandora City (Trường Chinh), Việt Nam]
# 17         Việt Nam           [53 Nguyễn Hồng Đào, Tân Bình, Việt Nam]
# 18         Việt Nam  [27b Sơn Kỳ ,phường Sơn Kỳ , Quận Tân Phú, Hồ ...
# 19         Việt Nam  [95 Gò Dầu, Thành phố Hồ Chí Minh, Thành phố H...
# 20         Việt Nam  [61 Trương Vĩnh Ký, Q.Tân Phú, Thành phố Hồ Ch...
# 21         Việt Nam  [Level 4, 1/1 Truong Chinh St., Tan Phu Dist, ...
# 22         Việt Nam                              [Bau Cat 2, Việt Nam]
# 23         Việt Nam    [266 Tô Hiệu, Q.Tân Phú, Hồ Chí Minh, Việt Nam]
# 24         Việt Nam    [Tân Sơn Nhì, Q.Tân Phú, Hồ Chí Minh, Việt Nam]
# 25         Việt Nam                       [41 Tân Canh Q.PN, Việt Nam]
# 26         Việt Nam                                         [Việt Nam]
# 27         Việt Nam  [78/1 (Phan Dinh Phung, Tan Phu), Thành phố Hồ...
# 28         Việt Nam  [61 Truong Cong Dinh St., Tan Binh Dist, Thành...
# 29         Việt Nam   [405/62/5 (Trường Chinh), Hồ Chí Minh, Việt Nam]
#
#                                      location.address location.postalCode  \
# 0                                                 NaN                 NaN
# 1                 1/1 Truong Chinh St., Tan Phu Dist.                 NaN
# 2                                                 NaN                 NaN
# 3   Ground Floor Viettel Complex Building, 285 Các...              700000
# 4   42 Đồng Xoài, phường 13, Tân Bình district, Pr...                 NaN
# 5                                                 NaN                 NaN
# 6                                             Độc Lập              760003
# 7                                                  55                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                   364 Cong Hoa St.                 NaN
# 11                          45 Đường Trương Công Định              736784
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14                     787 LUỸ BÁN BÍCH, QUẬN TÂN PHÚ                 NaN
# 15                                                NaN                 NaN
# 16                              Tầng 1, Pandora City                 NaN
# 17                                 53 Nguyễn Hồng Đào                 NaN
# 18           27b Sơn Kỳ ,phường Sơn Kỳ , Quận Tân Phú                 NaN
# 19                                          95 Gò Dầu                 NaN
# 20                       61 Trương Vĩnh Ký, Q.Tân Phú                 NaN
# 21        Level 4, 1/1 Truong Chinh St., Tan Phu Dist                 NaN
# 22                                          Bau Cat 2                 NaN
# 23                             266 Tô Hiệu, Q.Tân Phú                 NaN
# 24                             Tân Sơn Nhì, Q.Tân Phú                 NaN
# 25                                   41 Tân Canh Q.PN                 NaN
# 26                                                NaN                 NaN
# 27                                               78/1                 NaN
# 28             61 Truong Cong Dinh St., Tan Binh Dist                 NaN
# 29                                           405/62/5                 NaN
#
#               location.crossStreet
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5   184 To Hieu St., Tan Phu Dist.
# 6                              NaN
# 7                  Phan đình phùng
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                   Trường Chinh
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27        Phan Dinh Phung, Tan Phu
# 28                             NaN
# 29                    Trường Chinh
