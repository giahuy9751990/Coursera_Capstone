# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import geocoder
import folium
from geopy.geocoders import Nominatim # convert an address to langtitude and longitude
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# import k-means from clustering stage
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
url = "https://vi.wikipedia.org/wiki/Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh"

r  = requests.get(url)

data = r.text

soup = BeautifulSoup(data,'lxml')

# %%
df = []
for i in soup.find_all("table",class_="wikitable sortable")[0].find_all("tr"):
    ls = []
    for j in i.find_all("td"):
        ls.append(j.get_text())
    df.append(ls)
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#                                                  0            1         2    \
# 0                                               None         None      None
# 1  \n\n\nTên\n\nDiện tích (km²)\nDân số (người)\n...  Quận (19)\n  Quận 1\n
# 2                                               None         None      None
# 3                                        Quận (19)\n         None      None
# 4                                           Quận 1\n         7,72   142.000
#
#            3        4            5         6      7        8            9    \
# 0         None     None         None      None   None     None         None
# 1         7,72  142.000  10 phường\n  Quận 2\n  49,79  180.000  11 phường\n
# 2         None     None         None      None   None     None         None
# 3         None     None         None      None   None     None         None
# 4  10 phường\n     None         None      None   None     None         None
#
#    ...                  91         92      93       94                   95   \
# 0  ...                 None       None    None     None                 None
# 1  ...  1 thị trấn, 20 xã\n  Hóc Môn\n  109,17  542.000  1 thị trấn, 11 xã\n
# 2  ...                 None       None    None     None                 None
# 3  ...                 None       None    None     None                 None
# 4  ...                 None       None    None     None                 None
#
#         96      97       98                  99    100
# 0      None    None     None                None  None
# 1  Nhà Bè\n  100,43  206.000  1 thị trấn, 6 xã\n    \n
# 2      None    None     None                None  None
# 3      None    None     None                None  None
# 4      None    None     None                None  None
#
# [5 rows x 101 columns]

# %%
df.drop(labels=[0,1,2,3,16,24],inplace=True)
df = df.iloc[:,0:3]
df.columns=['District Name','Acreage (Km2)','Population']
df.reset_index(drop=True,inplace=True)
# Remove EOL "\n" String in dataset
for i in df.columns:
    df[i] = df[i].str.replace("\n","",regex=True)

# %%
df['Acreage (Km2)'] = df['Acreage (Km2)'].str.replace(",",".",regex=True)
df['Population'] = df['Population'].str.replace(".","",regex=True)
df['Acreage (Km2)'].astype(float)
df['Population'].astype(int)
# Out:
# 0     142000
# 1     180000
# 2     190000
# 3     175000
# 4     159000
# 5     233000
# 6     360000
# 7     424000
# 8     397000
# 9     234000
# 10    209000
# 11    620000
# 12    784000
# 13    499000
# 14    676000
# 15    163000
# 16    474000
# 17    485000
# 18    592000
# 19    705000
# 20     71000
# 21    462000
# 22    542000
# 23    206000
# Name: Population, dtype: int32

# %%
df.head()
# Out:
#   District Name Acreage (Km2) Population
# 0        Quận 1          7.72     142000
# 1        Quận 2         49.79     180000
# 2        Quận 3          4.92     190000
# 3        Quận 4          4.18     175000
# 4        Quận 5          4.27     159000

# %%
df.shape
# Out:
# (24, 3)

# %%
df_hcmc = df.copy()

# %% [markdown]
# ### Prepare for fourquare dataframe

# %%
CLIENT_ID = 'TYNGSEF0SNXTWZU5JEPMP3Z3BSCBA2TQEK2ODCGA114NG4GG' # your Foursquare ID
CLIENT_SECRET = 'G21UECLTFUK3MLIFP4SQK03OR1JMMDI4EPQS4J12TF0CFMP3' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TYNGSEF0SNXTWZU5JEPMP3Z3BSCBA2TQEK2ODCGA114NG4GG
# CLIENT_SECRET:G21UECLTFUK3MLIFP4SQK03OR1JMMDI4EPQS4J12TF0CFMP3

# %%
df_hcm_cor = pd.read_csv("HCM district coordinates.csv")

# %%
df_hcm_cor.head()
# Out:
#   District Name   Latitude   Longitude
# 0        Quận 1  10.777369  106.696646
# 1        Quận 2  10.782377  106.754713
# 2        Quận 3  10.780681  106.680866
# 3        Quận 4  10.758388  106.702021
# 4        Quận 5  10.755418  106.667333

# %%
df_hcm_cor = df_hcm_cor.sort_values(by="District Name",ascending=True)
df_hcmc = df_hcmc.sort_values(by="District Name",ascending=True)

# %%
df_hcm_cor['District Name'] == df_hcmc['District Name']
# Out:
# 19    True
# 13    True
# 12    True
# 20    True
# 21    True
# 14    True
# 22    True
# 23    True
# 15    True
# 0     True
# 9     True
# 10    True
# 11    True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 18    True
# 16    True
# 17    True
# Name: District Name, dtype: bool

# %%
df_hcmc = df_hcmc.merge(df_hcm_cor.iloc[:,1:3],left_index=True,right_index=True)

# %%
df_hcmc
# Out:
#    District Name Acreage (Km2) Population   Latitude   Longitude
# 19    Bình Chánh        252.56     705000  10.724583  106.575197
# 13    Bình Thạnh         20.78     499000  10.812639  106.714579
# 12      Bình Tân         52.02     784000  10.770324  106.599978
# 20       Cần Giờ        704.45      71000  10.535622  106.854503
# 21        Củ Chi        434.77     462000  11.008502  106.518123
# 14        Gò Vấp         19.73     676000  10.837427  106.666492
# 22       Hóc Môn        109.17     542000  10.891521  106.600013
# 23        Nhà Bè        100.43     206000  10.650182  106.729357
# 15     Phú Nhuận          4.88     163000  10.799939  106.677777
# 0         Quận 1          7.72     142000  10.777369  106.696646
# 9        Quận 10          5.72     234000  10.772549  106.669084
# 10       Quận 11          5.14     209000  10.764343  106.646925
# 11       Quận 12         52.74     620000  10.866624  106.657436
# 1         Quận 2         49.79     180000  10.782377  106.754713
# 2         Quận 3          4.92     190000  10.780681  106.680866
# 3         Quận 4          4.18     175000  10.758388  106.702021
# 4         Quận 5          4.27     159000  10.755418  106.667333
# 5         Quận 6          7.14     233000  10.747072  106.635760
# 6         Quận 7         35.69     360000  10.734714  106.725938
# 7         Quận 8         19.11     424000  10.730639  106.637651
# 8         Quận 9           114     397000  10.826519  106.816712
# 18       Thủ Đức          47.8     592000  10.857137  106.747156
# 16      Tân Bình         22.43     474000  10.810796  106.653959
# 17       Tân Phú         15.97     485000  10.790275  106.628605

# %%
address = 'Ho Chi Minh'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Ho Chi Minh City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Ho Chi Minh City are 10.7758439, 106.7017555.

# %%
m = folium.Map(location=[latitude, longitude],zoom_start=12)
#url = 'https://cocl.us/sanfran_geojson'
#geo_data_input = f'{url}'
for index,values in df_hcmc.iterrows():
    folium.CircleMarker(
        [values['Latitude'], values['Longitude']],
        radius=2,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(m)  
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'TYNGSEF0SNXTWZU5JEPMP3Z3BSCBA2TQEK2ODCGA114NG4GG' # your Foursquare ID
CLIENT_SECRET = 'G21UECLTFUK3MLIFP4SQK03OR1JMMDI4EPQS4J12TF0CFMP3' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TYNGSEF0SNXTWZU5JEPMP3Z3BSCBA2TQEK2ODCGA114NG4GG
# CLIENT_SECRET:G21UECLTFUK3MLIFP4SQK03OR1JMMDI4EPQS4J12TF0CFMP3

# %%
# type your answer here
def get_foursquare_url(cl_id,cl_se,ver,lat,long,radius):
    url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId=4bf58dd8d48988d1e0931735,5665c7b9498e7d8a4f2c0f06,5e18993feee47d000759b256,4bf58dd8d48988d1a1941735,4bf58dd8d48988d128941735,4bf58dd8d48988d16d941735,54135bf5e4b08f3d2429dfe7,56aa371be4b08b9a8d573508,54f4ba06498e2cf5561da814,4bf58dd8d48988d18d941735,4bf58dd8d48988d1f0941735'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        long, 
        radius, 
        )
    return url

# %%
results = requests.get(get_foursquare_url(CLIENT_ID,CLIENT_SECRET,VERSION,10.724583,106.575197,8960)).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e5ef3b014a126001bf1d005'},
#  'response': {'venues': [{'id': '5b288ec50868a2002c96b412',
#     'name': 'Wayne’s Coffee',
#     'location': {'address': 'Ground Floor Viettel Complex Building, 285 Cách Mạng Tháng Tám, Phường 12',
#      'lat': 10.78922,
#      'lng': 106.63663,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.78922,
#        'lng': 106.63663}],
#      'distance': 9844,
#      'postalCode': '700000',
#      'cc': 'VN',
#      'city': 'Ho Chi Minh City - Quận 10',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Ground Floor Viettel Complex Building, 285 Cách Mạng Tháng Tám, Phường 12',
#       'Ho Chi Minh City - Quận 10',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5b6d5a08121384002c083f89',
#     'name': 'passio',
#     'location': {'crossStreet': 'LUCKY PALACE',
#      'lat': 10.749037,
#      'lng': 106.653464,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.749037,
#        'lng': 106.653464}],
#      'distance': 8982,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['LUCKY PALACE',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5dabb5d4bfb9f2000804bb66',
#     'name': 'Phúc Long tea & coffee - lê quang sung st,.',
#     'location': {'address': '4 Lê Quang Sung St., W2, D6',
#      'crossStreet': 'Phạm Đình Hổ St,.',
#      'lat': 10.750984,
#      'lng': 106.649701,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.750984,
#        'lng': 106.649701}],
#      'distance': 8662,
#      'postalCode': '700000',
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['4 Lê Quang Sung St., W2, D6 (Phạm Đình Hổ St,.)',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5e1c169c6356c10008901cb6',
#     'name': 'Cafe 268',
#     'location': {'lat': 10.763842,
#      'lng': 106.644311,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.763842,
#        'lng': 106.644311}],
#      'distance': 8731,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5bd7a2dea0215b002c481285',
#     'name': 'Trung Nguyên Legend',
#     'location': {'address': '807 Tạ Quang Bửu, P.5, Q.8',
#      'lat': 10.736383,
#      'lng': 106.669937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.736383,
#        'lng': 106.669937}],
#      'distance': 10444,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['807 Tạ Quang Bửu, P.5, Q.8',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '4d2284126e8c3704d2a10ca0',
#     'name': '7 Kỳ Quang 七奇觀',
#     'location': {'address': 'So 12 Duong 26',
#      'crossStreet': 'P.11 Q.6',
#      'lat': 10.741957477887363,
#      'lng': 106.63233965432391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.741957477887363,
#        'lng': 106.63233965432391}],
#      'distance': 6542,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['So 12 Duong 26 (P.11 Q.6)',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '4dbf9d44043706a0320254db',
#     'name': 'Cà phê Vườn Đá - Stone Garden',
#     'location': {'address': '3 Hòa Bình, Ward 3, Dist 11',
#      'lat': 10.7668842959117,
#      'lng': 106.64000153560487,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.7668842959117,
#        'lng': 106.64000153560487}],
#      'distance': 8509,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['3 Hòa Bình, Ward 3, Dist 11',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5cc91ec05ba04600396e48e1',
#     'name': 'Bodyfriend Massage Coffee',
#     'location': {'lat': 10.800833,
#      'lng': 106.61616,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.800833,
#        'lng': 106.61616}],
#      'distance': 9597,
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Hồ Chí Minh', 'Việt Nam']},
#     'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#       'name': 'Corporate Coffee Shop',
#       'pluralName': 'Corporate Coffee Shops',
#       'shortName': 'Corporate Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '4f86d20ae4b05dd564805736',
#     'name': 'Cafe 55 phan đình phùng',
#     'location': {'address': '55',
#      'crossStreet': 'Phan đình phùng',
#      'lat': 10.78959174365355,
#      'lng': 106.63051477678941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.78959174365355,
#        'lng': 106.63051477678941}],
#      'distance': 9432,
#      'cc': 'VN',
#      'city': 'Hcm',
#      'country': 'Việt Nam',
#      'formattedAddress': ['55 (Phan đình phùng)', 'Hcm', 'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5c98aac6fd16bb0039968509',
#     'name': 'Trung Nguyen Legend Cafe',
#     'location': {'lat': 10.749765,
#      'lng': 106.6502,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.749765,
#        'lng': 106.6502}],
#      'distance': 8668,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5954920465211f741f672a8f',
#     'name': 'The Coffee House Bình Phú',
#     'location': {'address': '111 Bình Phú, Khu IV, Quận 6',
#      'lat': 10.743174,
#      'lng': 106.63014,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.743174,
#        'lng': 106.63014}],
#      'distance': 6355,
#      'postalCode': '747145',
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['111 Bình Phú, Khu IV, Quận 6',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '57cd283b498ecc39cb07542c',
#     'name': 'Highland Coffee Tùng Thiện Vương',
#     'location': {'lat': 10.745817,
#      'lng': 106.658601,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.745817,
#        'lng': 106.658601}],
#      'distance': 9423,
#      'cc': 'VN',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5e5240407f39440008eba736',
#     'name': 'Cao Coffee',
#     'location': {'lat': 10.787477,
#      'lng': 106.62361,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.787477,
#        'lng': 106.62361}],
#      'distance': 8777,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '52f79dff11d2ba07c640abd2',
#     'name': 'Miền Thảo Mộc Café',
#     'location': {'address': '554E Minh Phụng, P9, Q11',
#      'crossStreet': 'Minh Phụng',
#      'lat': 10.763034700967966,
#      'lng': 106.64513960384872,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.763034700967966,
#        'lng': 106.64513960384872}],
#      'distance': 8765,
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['554E Minh Phụng, P9, Q11 (Minh Phụng)',
#       'Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5bcafa784c954c002c6c81d4',
#     'name': 'the coffee house',
#     'location': {'lat': 10.786697,
#      'lng': 106.64347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.786697,
#        'lng': 106.64347}],
#      'distance': 10176,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '591d40429b047319cb3f01cb',
#     'name': 'The Coffee House',
#     'location': {'address': 'Độc Lập',
#      'lat': 10.792879,
#      'lng': 106.628855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.792879,
#        'lng': 106.628855}],
#      'distance': 9603,
#      'postalCode': '760003',
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Độc Lập', 'Thành phố Hồ Chí Minh', 'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '52c6b8a7498e32caa049a983',
#     'name': 'Food Court @ AEON Mall',
#     'location': {'lat': 10.801273228474118,
#      'lng': 106.61788012492114,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.801273228474118,
#        'lng': 106.61788012492114}],
#      'distance': 9729,
#      'cc': 'VN',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5d2fc864be438a00083207dd',
#     'name': 'Passio Coffee',
#     'location': {'address': '25 Dương Quang Đông, Q.8',
#      'lat': 10.737923,
#      'lng': 106.667026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.737923,
#        'lng': 106.667026}],
#      'distance': 10152,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['25 Dương Quang Đông, Q.8',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5e325e8f30cb8c0008acfa99',
#     'name': 'Moon Fruit & Cafe',
#     'location': {'address': 'Moonlight Parkview, đường số 7, P. An Lạc A, Q. Bình Tân',
#      'lat': 10.751665,
#      'lng': 106.61958,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.751665,
#        'lng': 106.61958}],
#      'distance': 5714,
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Moonlight Parkview, đường số 7, P. An Lạc A, Q. Bình Tân',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '576836b5498e991e379191f1',
#     'name': 'Phúc Long Coffee & Tea House',
#     'location': {'address': 'G Flr., 1 Street 17A, Binh Tan Dist.',
#      'lat': 10.74336439289612,
#      'lng': 106.61242246627808,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.74336439289612,
#        'lng': 106.61242246627808}],
#      'distance': 4576,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['G Flr., 1 Street 17A, Binh Tan Dist.',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5e32986c5de197000871e1bf',
#     'name': 'Oxy House',
#     'location': {'address': 'Số 1-3, đường số 7, P. An Lạc A, Q. Bình Tân',
#      'lat': 10.751476,
#      'lng': 106.62258,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.751476,
#        'lng': 106.62258}],
#      'distance': 5984,
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Số 1-3, đường số 7, P. An Lạc A, Q. Bình Tân',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5c1a1fa0356b49002cabafc2',
#     'name': 'The Coffee House Bình Thới',
#     'location': {'address': 'Đường số 5, CX Bình Thới, Q11',
#      'crossStreet': 'Đường số 6',
#      'lat': 10.761811,
#      'lng': 106.64851,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.761811,
#        'lng': 106.64851}],
#      'distance': 9025,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Đường số 5, CX Bình Thới, Q11 (Đường số 6)',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5a916d52588e361c5d177eef',
#     'name': 'Jardin De Cafe',
#     'location': {'address': 'A10-Ehome 3, 103 Ho Hoc Lam, W.An Lac, D.Binh Tan',
#      'lat': 10.713166,
#      'lng': 106.611015,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.713166,
#        'lng': 106.611015}],
#      'distance': 4118,
#      'postalCode': '700000',
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['A10-Ehome 3, 103 Ho Hoc Lam, W.An Lac, D.Binh Tan',
#       'Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '4f3b2c81e4b036beb85fa115',
#     'name': 'Cà Phê Tháp Cổ',
#     'location': {'address': '9',
#      'crossStreet': '14',
#      'lat': 10.728230994410403,
#      'lng': 106.65281066942855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.728230994410403,
#        'lng': 106.65281066942855}],
#      'distance': 8498,
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['9 (14)', 'Hồ Chí Minh', 'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5947d6c526659b1af8c77579',
#     'name': 'The Coffee House (Vòng Xoay Mũi Tàu)',
#     'location': {'address': '1056 Hậu Giang, Quận 6',
#      'lat': 10.745629,
#      'lng': 106.625092,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.745629,
#        'lng': 106.625092}],
#      'distance': 5938,
#      'postalCode': '746641',
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['1056 Hậu Giang, Quận 6',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '57934cad498ef0947a5e00e5',
#     'name': 'Highlands Cofee AEON Mall Bình Tân',
#     'location': {'address': 'G Flr., 1 Street 17A, Binh Tan Dist.',
#      'lat': 10.74224,
#      'lng': 106.611443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.74224,
#        'lng': 106.611443}],
#      'distance': 4424,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['G Flr., 1 Street 17A, Binh Tan Dist.',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5b8ca052968f31002c043a94',
#     'name': 'The Coffee House',
#     'location': {'crossStreet': '184 To Hieu St., Tan Phu Dist.',
#      'lat': 10.7731495,
#      'lng': 106.627594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.7731495,
#        'lng': 106.627594}],
#      'distance': 7878,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['184 To Hieu St., Tan Phu Dist.',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5889f35692789f233348cc4f',
#     'name': 'The Coffee House (178 Hậu Giang)',
#     'location': {'address': '178 Hậu Giang, P6, Q6',
#      'lat': 10.749859,
#      'lng': 106.64363,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.749859,
#        'lng': 106.64363}],
#      'distance': 7995,
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['178 Hậu Giang, P6, Q6', 'Hồ Chí Minh', 'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '51e3463b498e0251d54e25c8',
#     'name': 'Cafe Điểm Hẹn',
#     'location': {'address': '2.4.6 Duong So 1, Khu Hiep An, Q.8',
#      'lat': 10.737955,
#      'lng': 106.66616,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.737955,
#        'lng': 106.66616}],
#      'distance': 10059,
#      'cc': 'VN',
#      'city': 'HCM',
#      'country': 'Việt Nam',
#      'formattedAddress': ['2.4.6 Duong So 1, Khu Hiep An, Q.8',
#       'HCM',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '53a4e261498e0b947ffff88a',
#     'name': "Lu's Coffee",
#     'location': {'address': '229B Pham Hung, Q8',
#      'lat': 10.738343289278301,
#      'lng': 106.67009023398549,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.738343289278301,
#        'lng': 106.67009023398549}],
#      'distance': 10491,
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['229B Pham Hung, Q8',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False}],
#   'confident': False}}

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e5ef3b014a126001bf1d005'},
#  'response': {'venues': [{'id': '5b288ec50868a2002c96b412',
#     'name': 'Wayne’s Coffee',
#     'location': {'address': 'Ground Floor Viettel Complex Building, 285 Cách Mạng Tháng Tám, Phường 12',
#      'lat': 10.78922,
#      'lng': 106.63663,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.78922,
#        'lng': 106.63663}],
#      'distance': 9844,
#      'postalCode': '700000',
#      'cc': 'VN',
#      'city': 'Ho Chi Minh City - Quận 10',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Ground Floor Viettel Complex Building, 285 Cách Mạng Tháng Tám, Phường 12',
#       'Ho Chi Minh City - Quận 10',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5b6d5a08121384002c083f89',
#     'name': 'passio',
#     'location': {'crossStreet': 'LUCKY PALACE',
#      'lat': 10.749037,
#      'lng': 106.653464,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.749037,
#        'lng': 106.653464}],
#      'distance': 8982,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['LUCKY PALACE',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5dabb5d4bfb9f2000804bb66',
#     'name': 'Phúc Long tea & coffee - lê quang sung st,.',
#     'location': {'address': '4 Lê Quang Sung St., W2, D6',
#      'crossStreet': 'Phạm Đình Hổ St,.',
#      'lat': 10.750984,
#      'lng': 106.649701,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.750984,
#        'lng': 106.649701}],
#      'distance': 8662,
#      'postalCode': '700000',
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['4 Lê Quang Sung St., W2, D6 (Phạm Đình Hổ St,.)',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5e1c169c6356c10008901cb6',
#     'name': 'Cafe 268',
#     'location': {'lat': 10.763842,
#      'lng': 106.644311,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.763842,
#        'lng': 106.644311}],
#      'distance': 8731,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5bd7a2dea0215b002c481285',
#     'name': 'Trung Nguyên Legend',
#     'location': {'address': '807 Tạ Quang Bửu, P.5, Q.8',
#      'lat': 10.736383,
#      'lng': 106.669937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.736383,
#        'lng': 106.669937}],
#      'distance': 10444,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['807 Tạ Quang Bửu, P.5, Q.8',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '4d2284126e8c3704d2a10ca0',
#     'name': '7 Kỳ Quang 七奇觀',
#     'location': {'address': 'So 12 Duong 26',
#      'crossStreet': 'P.11 Q.6',
#      'lat': 10.741957477887363,
#      'lng': 106.63233965432391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.741957477887363,
#        'lng': 106.63233965432391}],
#      'distance': 6542,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['So 12 Duong 26 (P.11 Q.6)',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '4dbf9d44043706a0320254db',
#     'name': 'Cà phê Vườn Đá - Stone Garden',
#     'location': {'address': '3 Hòa Bình, Ward 3, Dist 11',
#      'lat': 10.7668842959117,
#      'lng': 106.64000153560487,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.7668842959117,
#        'lng': 106.64000153560487}],
#      'distance': 8509,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['3 Hòa Bình, Ward 3, Dist 11',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5cc91ec05ba04600396e48e1',
#     'name': 'Bodyfriend Massage Coffee',
#     'location': {'lat': 10.800833,
#      'lng': 106.61616,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.800833,
#        'lng': 106.61616}],
#      'distance': 9597,
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Hồ Chí Minh', 'Việt Nam']},
#     'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#       'name': 'Corporate Coffee Shop',
#       'pluralName': 'Corporate Coffee Shops',
#       'shortName': 'Corporate Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '4f86d20ae4b05dd564805736',
#     'name': 'Cafe 55 phan đình phùng',
#     'location': {'address': '55',
#      'crossStreet': 'Phan đình phùng',
#      'lat': 10.78959174365355,
#      'lng': 106.63051477678941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.78959174365355,
#        'lng': 106.63051477678941}],
#      'distance': 9432,
#      'cc': 'VN',
#      'city': 'Hcm',
#      'country': 'Việt Nam',
#      'formattedAddress': ['55 (Phan đình phùng)', 'Hcm', 'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5c98aac6fd16bb0039968509',
#     'name': 'Trung Nguyen Legend Cafe',
#     'location': {'lat': 10.749765,
#      'lng': 106.6502,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.749765,
#        'lng': 106.6502}],
#      'distance': 8668,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5954920465211f741f672a8f',
#     'name': 'The Coffee House Bình Phú',
#     'location': {'address': '111 Bình Phú, Khu IV, Quận 6',
#      'lat': 10.743174,
#      'lng': 106.63014,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.743174,
#        'lng': 106.63014}],
#      'distance': 6355,
#      'postalCode': '747145',
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['111 Bình Phú, Khu IV, Quận 6',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '57cd283b498ecc39cb07542c',
#     'name': 'Highland Coffee Tùng Thiện Vương',
#     'location': {'lat': 10.745817,
#      'lng': 106.658601,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.745817,
#        'lng': 106.658601}],
#      'distance': 9423,
#      'cc': 'VN',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5e5240407f39440008eba736',
#     'name': 'Cao Coffee',
#     'location': {'lat': 10.787477,
#      'lng': 106.62361,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.787477,
#        'lng': 106.62361}],
#      'distance': 8777,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '52f79dff11d2ba07c640abd2',
#     'name': 'Miền Thảo Mộc Café',
#     'location': {'address': '554E Minh Phụng, P9, Q11',
#      'crossStreet': 'Minh Phụng',
#      'lat': 10.763034700967966,
#      'lng': 106.64513960384872,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.763034700967966,
#        'lng': 106.64513960384872}],
#      'distance': 8765,
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['554E Minh Phụng, P9, Q11 (Minh Phụng)',
#       'Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5bcafa784c954c002c6c81d4',
#     'name': 'the coffee house',
#     'location': {'lat': 10.786697,
#      'lng': 106.64347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.786697,
#        'lng': 106.64347}],
#      'distance': 10176,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '591d40429b047319cb3f01cb',
#     'name': 'The Coffee House',
#     'location': {'address': 'Độc Lập',
#      'lat': 10.792879,
#      'lng': 106.628855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.792879,
#        'lng': 106.628855}],
#      'distance': 9603,
#      'postalCode': '760003',
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Độc Lập', 'Thành phố Hồ Chí Minh', 'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '52c6b8a7498e32caa049a983',
#     'name': 'Food Court @ AEON Mall',
#     'location': {'lat': 10.801273228474118,
#      'lng': 106.61788012492114,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.801273228474118,
#        'lng': 106.61788012492114}],
#      'distance': 9729,
#      'cc': 'VN',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5d2fc864be438a00083207dd',
#     'name': 'Passio Coffee',
#     'location': {'address': '25 Dương Quang Đông, Q.8',
#      'lat': 10.737923,
#      'lng': 106.667026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.737923,
#        'lng': 106.667026}],
#      'distance': 10152,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['25 Dương Quang Đông, Q.8',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5e325e8f30cb8c0008acfa99',
#     'name': 'Moon Fruit & Cafe',
#     'location': {'address': 'Moonlight Parkview, đường số 7, P. An Lạc A, Q. Bình Tân',
#      'lat': 10.751665,
#      'lng': 106.61958,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.751665,
#        'lng': 106.61958}],
#      'distance': 5714,
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Moonlight Parkview, đường số 7, P. An Lạc A, Q. Bình Tân',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '576836b5498e991e379191f1',
#     'name': 'Phúc Long Coffee & Tea House',
#     'location': {'address': 'G Flr., 1 Street 17A, Binh Tan Dist.',
#      'lat': 10.74336439289612,
#      'lng': 106.61242246627808,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.74336439289612,
#        'lng': 106.61242246627808}],
#      'distance': 4576,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['G Flr., 1 Street 17A, Binh Tan Dist.',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5e32986c5de197000871e1bf',
#     'name': 'Oxy House',
#     'location': {'address': 'Số 1-3, đường số 7, P. An Lạc A, Q. Bình Tân',
#      'lat': 10.751476,
#      'lng': 106.62258,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.751476,
#        'lng': 106.62258}],
#      'distance': 5984,
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Số 1-3, đường số 7, P. An Lạc A, Q. Bình Tân',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5c1a1fa0356b49002cabafc2',
#     'name': 'The Coffee House Bình Thới',
#     'location': {'address': 'Đường số 5, CX Bình Thới, Q11',
#      'crossStreet': 'Đường số 6',
#      'lat': 10.761811,
#      'lng': 106.64851,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.761811,
#        'lng': 106.64851}],
#      'distance': 9025,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['Đường số 5, CX Bình Thới, Q11 (Đường số 6)',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5a916d52588e361c5d177eef',
#     'name': 'Jardin De Cafe',
#     'location': {'address': 'A10-Ehome 3, 103 Ho Hoc Lam, W.An Lac, D.Binh Tan',
#      'lat': 10.713166,
#      'lng': 106.611015,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.713166,
#        'lng': 106.611015}],
#      'distance': 4118,
#      'postalCode': '700000',
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['A10-Ehome 3, 103 Ho Hoc Lam, W.An Lac, D.Binh Tan',
#       'Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '4f3b2c81e4b036beb85fa115',
#     'name': 'Cà Phê Tháp Cổ',
#     'location': {'address': '9',
#      'crossStreet': '14',
#      'lat': 10.728230994410403,
#      'lng': 106.65281066942855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.728230994410403,
#        'lng': 106.65281066942855}],
#      'distance': 8498,
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['9 (14)', 'Hồ Chí Minh', 'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5947d6c526659b1af8c77579',
#     'name': 'The Coffee House (Vòng Xoay Mũi Tàu)',
#     'location': {'address': '1056 Hậu Giang, Quận 6',
#      'lat': 10.745629,
#      'lng': 106.625092,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.745629,
#        'lng': 106.625092}],
#      'distance': 5938,
#      'postalCode': '746641',
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['1056 Hậu Giang, Quận 6',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '57934cad498ef0947a5e00e5',
#     'name': 'Highlands Cofee AEON Mall Bình Tân',
#     'location': {'address': 'G Flr., 1 Street 17A, Binh Tan Dist.',
#      'lat': 10.74224,
#      'lng': 106.611443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.74224,
#        'lng': 106.611443}],
#      'distance': 4424,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['G Flr., 1 Street 17A, Binh Tan Dist.',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5b8ca052968f31002c043a94',
#     'name': 'The Coffee House',
#     'location': {'crossStreet': '184 To Hieu St., Tan Phu Dist.',
#      'lat': 10.7731495,
#      'lng': 106.627594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.7731495,
#        'lng': 106.627594}],
#      'distance': 7878,
#      'cc': 'VN',
#      'city': 'Thành phố Hồ Chí Minh',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['184 To Hieu St., Tan Phu Dist.',
#       'Thành phố Hồ Chí Minh',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '5889f35692789f233348cc4f',
#     'name': 'The Coffee House (178 Hậu Giang)',
#     'location': {'address': '178 Hậu Giang, P6, Q6',
#      'lat': 10.749859,
#      'lng': 106.64363,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.749859,
#        'lng': 106.64363}],
#      'distance': 7995,
#      'cc': 'VN',
#      'city': 'Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['178 Hậu Giang, P6, Q6', 'Hồ Chí Minh', 'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '51e3463b498e0251d54e25c8',
#     'name': 'Cafe Điểm Hẹn',
#     'location': {'address': '2.4.6 Duong So 1, Khu Hiep An, Q.8',
#      'lat': 10.737955,
#      'lng': 106.66616,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.737955,
#        'lng': 106.66616}],
#      'distance': 10059,
#      'cc': 'VN',
#      'city': 'HCM',
#      'country': 'Việt Nam',
#      'formattedAddress': ['2.4.6 Duong So 1, Khu Hiep An, Q.8',
#       'HCM',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False},
#    {'id': '53a4e261498e0b947ffff88a',
#     'name': "Lu's Coffee",
#     'location': {'address': '229B Pham Hung, Q8',
#      'lat': 10.738343289278301,
#      'lng': 106.67009023398549,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 10.738343289278301,
#        'lng': 106.67009023398549}],
#      'distance': 10491,
#      'cc': 'VN',
#      'state': 'Thành phố Hồ Chí Minh',
#      'country': 'Việt Nam',
#      'formattedAddress': ['229B Pham Hung, Q8',
#       'Thành phố Hồ Chí Minh',
#       'Việt Nam']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583281118',
#     'hasPerk': False}],
#   'confident': False}}

# %%
venue = results['response']['venues']

# %%
venue.
