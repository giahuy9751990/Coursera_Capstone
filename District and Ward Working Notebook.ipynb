# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("HCM district and ward coordinates.csv")

# %%
df
# Out:
#             Tỉnh Thành Phố  Mã TP     Quận Huyện  Mã QH  \
# 0    Thành phố Hồ Chí Minh     79         Quận 1    760
# 1    Thành phố Hồ Chí Minh     79         Quận 1    760
# 2    Thành phố Hồ Chí Minh     79         Quận 1    760
# 3    Thành phố Hồ Chí Minh     79         Quận 1    760
# 4    Thành phố Hồ Chí Minh     79         Quận 1    760
# ..                     ...    ...            ...    ...
# 317  Thành phố Hồ Chí Minh     79  Huyện Cần Giờ    787
# 318  Thành phố Hồ Chí Minh     79  Huyện Cần Giờ    787
# 319  Thành phố Hồ Chí Minh     79  Huyện Cần Giờ    787
# 320  Thành phố Hồ Chí Minh     79  Huyện Cần Giờ    787
# 321  Thành phố Hồ Chí Minh     79  Huyện Cần Giờ    787
#
#                    Phường Xã  Mã PX     Cấp  Tên Tiếng Anh   Latitude  \
# 0            Phường Tân Định  26734  Phường            NaN  10,792645
# 1              Phường Đa Kao  26737  Phường            NaN  10,789305
# 2            Phường Bến Nghé  26740  Phường            NaN  10,780322
# ...

# %%
df = df[['Tỉnh Thành Phố','Mã TP','Quận Huyện','Mã QH','Phường Xã','Mã PX','Cấp','Latitude','Longitude']]

# %%
df = df[['Mã PX','Phường Xã','Mã QH','Quận Huyện','Mã TP','Tỉnh Thành Phố','Latitude','Longitude']]

# %%
df.head()
# Out:
#    Mã PX                Phường Xã  Mã QH Quận Huyện  Mã TP  \
# 0  26734          Phường Tân Định    760     Quận 1     79
# 1  26737            Phường Đa Kao    760     Quận 1     79
# 2  26740          Phường Bến Nghé    760     Quận 1     79
# 3  26743         Phường Bến Thành    760     Quận 1     79
# 4  26746  Phường Nguyễn Thái Bình    760     Quận 1     79
#
#           Tỉnh Thành Phố   Latitude   Longitude
# 0  Thành phố Hồ Chí Minh  10,792645  106,690645
# 1  Thành phố Hồ Chí Minh  10,789305  106,698753
# 2  Thành phố Hồ Chí Minh  10,780322  106,704141
# 3  Thành phố Hồ Chí Minh  10,774806  106,495684
# 4  Thành phố Hồ Chí Minh  10,768872  106,701093

# %% [markdown]
# Ward Code
# Ward Name
# District Code
# District Name
# Province/City Code
# Province/City Name
# Latitude
# Longitude

# %%
df.columns=['Ward Code','Ward Name','District Code','District Name','Province/City Code','Province/City Name','Latitude','Longitude']

# %%
df.to_csv
# Out:
#      Ward Code                Ward Name  District Code  District Name  \
# 0        26734          Phường Tân Định            760         Quận 1
# 1        26737            Phường Đa Kao            760         Quận 1
# 2        26740          Phường Bến Nghé            760         Quận 1
# 3        26743         Phường Bến Thành            760         Quận 1
# 4        26746  Phường Nguyễn Thái Bình            760         Quận 1
# ..         ...                      ...            ...            ...
# 317      27670         Xã Tam Thôn Hiệp            787  Huyện Cần Giờ
# 318      27673          Xã An Thới Đông            787  Huyện Cần Giờ
# 319      27676              Xã Thạnh An            787  Huyện Cần Giờ
# 320      27679              Xã Long Hòa            787  Huyện Cần Giờ
# 321      27682               Xã Lý Nhơn            787  Huyện Cần Giờ
#
#      Province/City Code     Province/City Name   Latitude   Longitude
# ...

# %%
df.to_csv("HCM district and ward coordinates complete.csv")
